# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ['openai_api_key']=os.getenv('openai')           #ip->llm->o/p  no tool involved

# %%
from langchain.agents import create_agent

agent=create_agent(
    model='gpt-5',
    tools=[],
    system_prompt="you are a useful agent"

)

agent

# %%
response=agent.invoke({"message":["explain rag"]})
response[message]
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 response=agent.invoke({"message":["explain rag"]})
#       2 response
#
# File c:\Users\moham\Desktop\SLA\Langchainyt\.venv\Lib\site-packages\langgraph\pregel\main.py:3928, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3925             chunks.append(chunk)
#    3926 else:
#    3927     # v1: collect interrupts from updates stream
# -> 3928     for chunk in self.stream(
#    3929         input,
#    3930         config,
#    3931         context=context,
#    3932         stream_mode=(
#    3933             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3934         ),
#    3935         print_mode=print_mode,
#    3936         output_keys=output_keys,
# ...
